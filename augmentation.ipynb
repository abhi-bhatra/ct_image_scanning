# %%
from numpy import expand_dims
from keras.preprocessing import image
from matplotlib import pyplot
import tensorflow as tf

img = tf.keras.utils.load_img('E:\GSoC\ct_imaging\chest-ct\chest\ID_0057_AGE_0049_CONTRAST_0_CT.jpg')

dataImage = tf.keras.utils.img_to_array(img)

imageNew = expand_dims(dataImage, 0)

imageDataGen = image.ImageDataGenerator(horizontal_flip=True)

iterator = imageDataGen.flow(imageNew, batch_size=1)

for i in range(9):
	pyplot.subplot(330 + 1 + i)
	batch = iterator.next()
	img = batch[0].astype('uint8')
	pyplot.imshow(img)

pyplot.show()

# %%
import rotatedicom as rd

rd.rotate_dicom('E:\GSoC\ct_imaging\chest-ct\chest\ID_0057_AGE_0049_CONTRAST_0_CT.jpg', 'E:\GSoC\ct_imaging', 90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\GSoC\ct_imaging\augmentation.ipynb Cell 2 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/e%3A/GSoC/ct_imaging/augmentation.ipynb#ch0000001?line=0'>1</a> import rotatedicom as rd
# ----> <a href='vscode-notebook-cell:/e%3A/GSoC/ct_imaging/augmentation.ipynb#ch0000001?line=2'>3</a> rd.rotate_dicom('E:\GSoC\ct_imaging\chest-ct\chest\ID_0057_AGE_0049_CONTRAST_0_CT.jpg', 'E:\GSoC\ct_imaging', 90)
#
# AttributeError: module 'rotatedicom' has no attribute 'rotate_dicom'

# %%
import dicom2nifti

dicom2nifti.dicom_series_to_nifti('E:\\GSoC\\ct_imaging\\archive\\dicom_dir', 'E:\\GSoC\\ct_imaging\\temp', reorient_nifti=True)
# Out:
# Removing duplicate slice from series
# Removing duplicate slice from series
# Removing duplicate slice from series
# Removing duplicate slice from series
# Removing duplicate slice from series
# Removing duplicate slice from series
# Image orientations not consistent through all slices
# ---------------------------------------------------------
# [-1.  0.  0.] [1. 0. 0.]
# [ 0. -1.  0.] [0. 1. 0.]
# ---------------------------------------------------------
# ---------------------------------------------------------------------------
# ConversionValidationError                 Traceback (most recent call last)
# e:\GSoC\ct_imaging\augmentation.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/e%3A/GSoC/ct_imaging/augmentation.ipynb#ch0000002?line=0'>1</a> import dicom2nifti
# ----> <a href='vscode-notebook-cell:/e%3A/GSoC/ct_imaging/augmentation.ipynb#ch0000002?line=2'>3</a> dicom2nifti.dicom_series_to_nifti('E:\\GSoC\\ct_imaging\\archive\\dicom_dir', 'E:\\GSoC\\ct_imaging\\temp', reorient_nifti=True)
#
# File e:\animals\kerasenv\lib\site-packages\dicom2nifti\convert_dicom.py:77, in dicom_series_to_nifti(original_dicom_directory, output_file, reorient_nifti)
#      73     shutil.copytree(original_dicom_directory, dicom_directory)
#      75     dicom_input = common.read_dicom_directory(dicom_directory)
# ---> 77     return dicom_array_to_nifti(dicom_input, output_file, reorient_nifti)
#      79 except AttributeError as exception:
#      80     raise exception
#
# File e:\animals\kerasenv\lib\site-packages\dicom2nifti\convert_dicom.py:117, in dicom_array_to_nifti(dicom_list, output_file, reorient_nifti)
#     114 vendor = _get_vendor(dicom_list)
#     116 if vendor == Vendor.GENERIC:
# --> 117     results = convert_generic.dicom_to_nifti(dicom_list, output_file)
#     118 elif vendor == Vendor.SIEMENS:
#     119     results = convert_siemens.dicom_to_nifti(dicom_list, output_file)
#
# File e:\animals\kerasenv\lib\site-packages\dicom2nifti\convert_generic.py:119, in dicom_to_nifti(dicom_input, output_file)
#     116     common.validate_slicecount(dicom_input)
#     117 if settings.validate_orientation:
#     118     # validate that all slices have the same orientation
# --> 119     common.validate_orientation(dicom_input)
#     120 if settings.validate_orthogonal:
#     121     # validate that we have an orthogonal image (to detect gantry tilting etc)
#     122     common.validate_orthogonal(dicom_input)
#
# File e:\animals\kerasenv\lib\site-packages\dicom2nifti\common.py:960, in validate_orientation(dicoms)
#     958 logger.warning('%s %s' % (image_orient2, first_image_orient2))
#     959 logger.warning('---------------------------------------------------------')
# --> 960 raise ConversionValidationError('IMAGE_ORIENTATION_INCONSISTENT')
#
# ConversionValidationError: IMAGE_ORIENTATION_INCONSISTENT

# %%
# SimpleITK to check orientation of DICOM image
import SimpleITK as sitk

series_IDs = sitk.ImageSeriesReader.GetGDCMSeriesIDs('E:\\GSoC\\ct_imaging\\archive\\dicom_dir')
series_IDs
# Out:
# ('1.3.6.1.4.1.14519.5.2.1.3023.4012.102289758600639081883682341599',
#  '1.3.6.1.4.1.14519.5.2.1.3023.4012.111970507245102440072981773069',
#  '1.3.6.1.4.1.14519.5.2.1.3023.4012.154470741269083988898569715734',
#  '1.3.6.1.4.1.14519.5.2.1.3023.4012.251486101984782457779149100338',
#  '1.3.6.1.4.1.14519.5.2.1.3023.4012.281222452204153314922270968637',
#  '1.3.6.1.4.1.14519.5.2.1.3023.4012.297267439816180432188742253053',
#  '1.3.6.1.4.1.14519.5.2.1.3023.4012.513523794062613324810980652054',
#  '1.3.6.1.4.1.14519.5.2.1.3023.4012.648531603410109839170055154074',
#  '1.3.6.1.4.1.14519.5.2.1.3023.4012.695837418985624676340861607694',
#  '1.3.6.1.4.1.14519.5.2.1.6450.4012.153444090734536905415278769671',
#  '1.3.6.1.4.1.14519.5.2.1.6450.4012.175016803370372621275285549100',
#  '1.3.6.1.4.1.14519.5.2.1.6450.4012.185965196167856618864777448062',
#  '1.3.6.1.4.1.14519.5.2.1.6450.4012.200234714530375524999580843628',
#  '1.3.6.1.4.1.14519.5.2.1.6450.4012.249320450296411760831322037482',
#  '1.3.6.1.4.1.14519.5.2.1.6450.4012.288687105792976930431435647528',
#  '1.3.6.1.4.1.14519.5.2.1.6450.4012.329553752453253440797880650254',
#  '1.3.6.1.4.1.14519.5.2.1.6450.4012.817843454204409022668627882451',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.100084189012742939741493476990',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.100906133174671643622098090906',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.103610518164000779098628407278',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.185498582525296662848624544683',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.188649944158258613292939522236',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.200341997905627984892937825671',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.217367240046972683989491086440',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.243448495980906058874266499183',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.257122354531874084887233351164',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.292238797046224306456366984922',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.298706900388269656177091542700',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.324210268305642074248644121036',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.334752481840162574804029567948',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.474856310072238036275779300360',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.538737805847710723629543870053',
#  '1.3.6.1.4.1.14519.5.2.1.6450.9002.889939672884497349379152577060',
#  '1.3.6.1.4.1.14519.5.2.1.7777.4012.113612831763727651180754259632',
#  '1.3.6.1.4.1.14519.5.2.1.7777.4012.142543356326839418890068959846',
#  '1.3.6.1.4.1.14519.5.2.1.7777.4012.187415951615560924142151552727',
#  '1.3.6.1.4.1.14519.5.2.1.7777.4012.199686864909373602515797626335',
#  '1.3.6.1.4.1.14519.5.2.1.7777.4012.229225923801272533692298691763',
#  '1.3.6.1.4.1.14519.5.2.1.7777.4012.261024172548059108431426343179',
#  '1.3.6.1.4.1.14519.5.2.1.7777.4012.266696635521527146394727954993',
#  '1.3.6.1.4.1.14519.5.2.1.7777.4012.540171124625453976234946363979',
#  '1.3.6.1.4.1.14519.5.2.1.7777.4012.690957267784060587771729198271',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.105975861091828376543602528972',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.106684271246229903146411807044',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.107011676899677159680384544120',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.129564277768240477678335802727',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.134999765519851780539173272100',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.141834388005746288842544795566',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.144176020587949545663031202320',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.149281226664864328153997867180',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.156193230572698742469080278763',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.161807710484306441994001654470',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.164993732028074168253800990636',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.165708103986548541817506738541',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.189589030551789583421796695637',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.198754632690942685150635177035',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.203750259308881185318237682745',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.209310199253842172079582692625',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.221217998899002004397800887612',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.223492001507807713410406729536',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.225087702348577650904688103056',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.227571573286142502566010959726',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.231169414301528210714189934818',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.243904225108685263924887046265',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.246606807181055791884070217538',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.257779709992861959301614962520',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.272923823647562637898540440382',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.276979399257180200489703215689',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.277694159037979697805931678014',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.282617070529060301401540230240',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.282728678064040680721993436859',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.289608635298460430761185724274',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.292908361479843442518824858190',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.310346392770532913119802259246',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.325289574171158871203259661119',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.329585390340124172771998774364',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.330040580300121811467658418579',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.331520134866128347195087757479',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.332002723476583484085948161666',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.335607746166421447688402796816',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.337437172984704735750825031349',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.339047862535848462266195729485',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.498141160054996376978530311535',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.531955806841803044139009743992',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.565961750064103733875570289330',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.662367505524593758581644994111',
#  '1.3.6.1.4.1.14519.5.2.1.7777.9002.977841843288532989542336586767',
#  '1.3.6.1.4.1.14519.5.2.1.8421.4012.196400828955909049702504159535',
#  '1.3.6.1.4.1.14519.5.2.1.8421.4012.212567384761119393688297250473',
#  '1.3.6.1.4.1.14519.5.2.1.8421.4012.249497698493366956124363607513',
#  '1.3.6.1.4.1.14519.5.2.1.8421.4012.657552380641072306743475217005',
#  '1.3.6.1.4.1.14519.5.2.1.8421.4012.810828569510033424505264986865',
#  '1.3.6.1.4.1.14519.5.2.1.8421.4012.905460266874649251053314776511',
#  '1.3.6.1.4.1.14519.5.2.1.8421.9002.135538674486317239740817858802',
#  '1.3.6.1.4.1.14519.5.2.1.8421.9002.500879414859935210155630180876')

# %%
data_directory='E:\\GSoC\\ct_imaging\\archive\\dicom_dir'
series_file_names = sitk.ImageSeriesReader.GetGDCMSeriesFileNames(data_directory, series_IDs[0])
series_file_names
# Out:
# ('E:\\GSoC\\ct_imaging\\archive\\dicom_dir\\ID_0078_AGE_0066_CONTRAST_0_CT.dcm',)

# %%
series_reader = sitk.ImageSeriesReader()
series_reader.SetFileNames(series_file_names)
series_reader.LoadPrivateTagsOn()
image3D=series_reader.Execute()
size = image3D.GetSize()

# %%
size
# Out:
# (512, 512, 1)

# %%
reoriented = sitk.DICOMOrient(img, 'LPS')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\GSoC\ct_imaging\augmentation.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/GSoC/ct_imaging/augmentation.ipynb#ch0000007?line=0'>1</a> reoriented = sitk.DICOMOrient(img, 'LPS')
#
# File e:\animals\kerasenv\lib\site-packages\SimpleITK\SimpleITK.py:20344, in DICOMOrient(*args, **kwargs)
#   20342 def DICOMOrient(*args, **kwargs):
#   20343     r"""DICOMOrient(Image image1, std::string desiredCoordinateOrientation=std::string("LPS")) -> Image"""
# > 20344     return _SimpleITK.DICOMOrient(*args, **kwargs)
#
# TypeError: in method 'DICOMOrient', argument 1 of type 'itk::simple::Image const &'
